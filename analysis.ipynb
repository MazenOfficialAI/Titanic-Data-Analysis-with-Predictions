# %% [markdown]
# Importing the modules

# %%
import pandas as pd

# %%
import os


os.getcwd()
# Out:
# 'd:\\Portofilo\\titanic\\notebooks'

# %%
df = pd.read_csv(r"D:\Portofilo\titanic\data\procesed.csv")
print(df.head(5))

print(df.tail(5))
